# %%
import stanza
from nltk import Tree
stanza.download('en')
nlp = stanza.Pipeline('en')
import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# 2022-01-13 16:34:17 INFO: Downloading default packages for language: en (English)...
# 2022-01-13 16:34:18 INFO: File exists: /Users/saharatif/stanza_resources/en/default.zip.
# 2022-01-13 16:34:21 INFO: Finished downloading models and saved to /Users/saharatif/stanza_resources.
# 2022-01-13 16:34:21 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# ...
#
# 2022-01-13 16:34:21 INFO: Use device: cpu
# 2022-01-13 16:34:21 INFO: Loading: tokenize
# 2022-01-13 16:34:21 INFO: Loading: pos
# 2022-01-13 16:34:21 INFO: Loading: lemma
# 2022-01-13 16:34:21 INFO: Loading: depparse
# 2022-01-13 16:34:22 INFO: Loading: sentiment
# 2022-01-13 16:34:22 INFO: Loading: ner
# 2022-01-13 16:34:23 INFO: Done loading processors!

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# TEST

# %%
import stanza
from nltk import Tree
stanza.download('en')
nlp = stanza.Pipeline('en')
import warnings
warnings.filterwarnings('ignore')
import benepar, spacy
nlp = spacy.load('en_core_web_sm')
if spacy.__version__.startswith('2'):
    nlp.add_pipe(benepar.BeneparComponent("benepar_en3"))
else:
    nlp.add_pipe("benepar", config={"model": "benepar_en3"})

import re
define_words = 'and other '
for i, line in enumerate(open('CNN_articles.txt','r')):
    for match in re.findall(r"([^.]*?%s[^.]*\.)" % define_words,line):
        match=match.replace('"', '')
        pattern = 'NP < CC'
        matches = client.tregex(match, pattern)

        if (matches['sentences'])== [{}] or (matches['sentences'])=={} or (matches['sentences'][0]== {}):
            break
        else:
            print(matches['sentences'][0]['0']['spanString'])
            print('\n')
# Out:
# 2022-01-13 16:35:14 INFO: Starting server with command: java -Xmx16G -cp /Users/saharatif/stanza_corenlp/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 30000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-a79b70ade03a4043.props -annotators tokenize,ssplit,pos,lemma,ner,parse,depparse -preload -outputFormat serialized
# police , and other possible charges
#
#
# the father , 24 , and other family members
#
#
# the father and other family members
#
#
# the family and other patrons
#
#
# kazakhstan , colombia , haiti , and other places
#
#
# football and celebrity
#
#
# the stats and other players
#
#
# chemotherapy and other hospital fees
#
#
# a bronchitis-related cough and other issues
#
#
# these and other new coloring book titles
#
#
# rape , aggravated assault , conspiracy , child endangerment and other counts
#
#
# iinet and other isps
#
#
# widespread cannibalism and other macabre rituals
#
#
# ...

# %% [markdown]
# FILE WRITE

# %%
file_tregex=open("NP<<CC_tregex_parse.txt","a+")

# %%
import benepar, spacy
nlp = spacy.load('en_core_web_sm')
if spacy.__version__.startswith('2'):
    nlp.add_pipe(benepar.BeneparComponent("benepar_en3"))
else:
    nlp.add_pipe("benepar", config={"model": "benepar_en3"})

import re
define_words = 'and other '
for i, line in enumerate(open('CNN_articles.txt','r')):
    for match in re.findall(r"([^.]*?%s[^.]*\.)" % define_words,line):
        doc=nlp(match)
        #print (i,"-", match)
        sent = list(doc.sents)[0]
        #print('\n')
        pattern = 'NP << CC'
        matches = client.tregex(match, pattern)
        
#         print (i,"-", match)
#         file_tregex.write(str(i))
        file_tregex.write(str(match))
        file_tregex.write('\n')

        
        if (matches['sentences'])== [{}]:
#             print('no match')
            file_tregex.write('\n')
            
        elif (matches['sentences'][0])=={}:
#             print(matches['sentences'][1]['0']['spanString'])
            file_tregex.write(matches['sentences'][1]['0']['match'])
            file_tregex.write('\n')
        else:
#             print(matches['sentences'][0]['0']['spanString'])
            file_tregex.write(matches['sentences'][0]['0']['match'])
            file_tregex.write('\n')
file_tregex.close()

# %%
from stanza.server import CoreNLPClient
from nltk import Tree
# stanza.install_corenlp()


text = "lynda anderson wrote , posting outrageous things in a pathetic attempt to stay relevant ? negotiations are coming down to the wire between iran , the united states and other nations on restricting tehran 's nuclear program to prevent the ability to develop an atomic bomb ."
text1='the mans heartbroken parents , son and other relatives'
text2='similar stories of women and girls being harassed on local transportation and other public spaces'
with CoreNLPClient(
        annotators=['tokenize','ssplit','pos','lemma','ner', 'parse', 'depparse'],
        timeout=30000,
        memory='16G', be_quiet=False) as client:
    pattern = 'NP < JJ ' #NP<JJ, NP<NN
    matches = client.tregex(text1, pattern)
#     print(matches['sentences'][0])
    print(matches['sentences'][0]['0']['match']) # prints: "(NP (DT a) (JJ simple) (NN sentence))\n"
#     t = Tree.fromstring(str(matches['sentences'][1]['0']['match']))
#     print (' '.join(t.leaves()))
# Out:
# 2022-01-15 14:38:13 INFO: Writing properties to tmp file: corenlp_server-c5ff8b3a3b754510.props
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/stanza/server/client.py in start(self)
#     131                     try:
# --> 132                         sock.bind((self.host, self.port))
#     133                     except socket.error:
#
# OSError: [Errno 48] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# PermanentlyFailedException                Traceback (most recent call last)
# <ipython-input-11-e44d2c952b06> in <module>
#       7 text1='the mans heartbroken parents , son and other relatives'
#       8 text2='similar stories of women and girls being harassed on local transportation and other public spaces'
# ----> 9 with CoreNLPClient(
# ...

# %%
from stanza.server import CoreNLPClient
text = " What saved many farmers from a bad year was the opportunity to reclaim large quantities of grain and other crops that they had 'mortgaged' to the government under price-support loan programs."
with CoreNLPClient(
        annotators=['tokenize','ssplit','pos','lemma','ner', 'parse', 'depparse'],
        timeout=30000,
        memory='16G', be_quiet=False) as client:
    pattern = 'NP << CC'
    matches = client.tregex(text, pattern)
    print(matches['sentences'])
    print(matches['sentences'][0]['0']['match']) # prints: "(NP (DT a) (JJ simple) (NN sentence))\n"
# Out:
# 2022-01-15 14:38:25 INFO: Writing properties to tmp file: corenlp_server-3a4cd250c9644ef9.props
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/stanza/server/client.py in start(self)
#     131                     try:
# --> 132                         sock.bind((self.host, self.port))
#     133                     except socket.error:
#
# OSError: [Errno 48] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# PermanentlyFailedException                Traceback (most recent call last)
# <ipython-input-12-4b67028a4be1> in <module>
#       1 from stanza.server import CoreNLPClient
#       2 text = " What saved many farmers from a bad year was the opportunity to reclaim large quantities of grain and other crops that they had 'mortgaged' to the government under price-support loan programs."
# ...
